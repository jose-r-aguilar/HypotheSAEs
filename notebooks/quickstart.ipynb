# %%
# HypotheSAEs Quickstart
# This notebook demonstrates basic usage of HypotheSAEs on a sample of the Yelp review dataset

# %load_ext autoreload
# %autoreload 2

import os
os.environ['OPENAI_KEY_SAE'] = os.environ['OPENAI_API_KEY'] # Replace with your OpenAI API key, or with another environment variable (e.g. os.environ['OPENAI_API_KEY'])

import numpy as np
import pandas as pd

from hypothesaes.quickstart import train_sae, interpret_sae, generate_hypotheses, evaluate_hypotheses
from hypothesaes.embedding import get_openai_embeddings, get_local_embeddings

# %% [markdown]
# **Load data**
#
# The dataset we're using here is a subset of 20K Yelp reviews, with 2K reviews used for validation (during SAE training).
#
# The target variable is the `stars` column, which is a rating between 1 and 5. We treat this as a regression task.
#
# There are also 2K reviews used for holdout evaluation, which we'll use at the end of the notebook.

# %%
from sklearn.model_selection import train_test_split
current_dir = os.getcwd()
if current_dir.endswith("notebooks"):
    prefix = "../"
else:
    prefix = "./"

base_dir = os.path.join(prefix, "demo-data")
'''
train_df = pd.read_json(os.path.join(base_dir, "yelp-demo-train-20K.json"), lines=True)
val_df = pd.read_json(os.path.join(base_dir, "yelp-demo-val-2K.json"), lines=True)

texts = train_df['text'].tolist()
labels = train_df['stars'].values
val_texts = val_df['text'].tolist() # These are only used for early stopping of SAE training, so we don't need labels.
'''

data_path = os.path.join(base_dir, "cmf_data_position.txt")  # unified full data file

# Read in the full dataset (tab-separated, no header)
df = pd.read_csv(data_path, sep='\t', header=None, names=["label", "text"])
df.head()
# Remove rows with label == 0
df = df[df["label"] != "0"]

# Shuffle and split into train (90%) and validation (10%)
train_df, val_df = train_test_split(df, test_size=0.1, random_state=42, stratify=df["label"])

# Extract inputs
texts = train_df["text"].tolist()
labels = train_df["label"].values
val_texts = val_df["text"].tolist()
val_labels = val_df["label"].values  # optional, for evaluation
# Out:
#    label                                               text
# 0     -1  it all about the a in fape is the purpose of t...
# 1      1                                pass the framework
# 2      1  dear members of the state board of education a...
# 3      1  i am writing to support offering algebra to 8t...
# 4     -1  just stop messing with our math leave math alo...

# %% [markdown]
# **Compute text embeddings for your dataset**
#
# We'll compute text embeddings for a training set, and optionally a validation set. The validation embeddings are used for SAE eval and early-stopping during training.
#
# Embeddings will be stored in the `emb_cache` directory (or `os.environ["EMB_CACHE_DIR"]` if you set it) using the `cache_name` parameter, so you only need to compute embeddings once.
#
# You can use OpenAI or a local model.
#
# Local models will run much faster on GPU. The default local model is `nomic-ai/modernbert-embed-base`. You can use any sentence-transformers model, but please read the model's docs; you may need to edit `get_local_embeddings`.

# %%
EMBEDDER = "text-embedding-3-small" # OpenAI
# EMBEDDER = "nomic-ai/modernbert-embed-base" # Huggingface model, will run locally
CACHE_NAME = f"cmf_quickstart_{EMBEDDER}"

text2embedding = get_openai_embeddings(texts + val_texts, model=EMBEDDER, cache_name=CACHE_NAME)
# text2embedding = get_local_embeddings(texts + val_texts, model=EMBEDDER, batch_size=128, cache_name=CACHE_NAME)
embeddings = np.stack([text2embedding[text] for text in texts])

train_embeddings = np.stack([text2embedding[text] for text in texts])
val_embeddings = np.stack([text2embedding[text] for text in val_texts])
# Out:
# Processing chunks:   0%|          | 0/1 [00:00<?, ?it/s]
# Chunk 0:   0%|          | 0/3 [00:00<?, ?it/s]
# /Users/joseaguilar/Documents/HypotheSAEs/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Saved 543 embeddings to /Users/joseaguilar/Documents/HypotheSAEs/emb_cache/cmf_quickstart_text-embedding-3-small/chunk_000.npy

# %% [markdown]
# **Train SAE(s)**
#
# Using different values of $M$ and $k$ will produce features at different levels of granularity. You can train multiple SAEs if you'd like to produce features at varying granularity, but this is optional.
#
# See the README for more details about selecting $M$ and $k$.

# %%
checkpoint_dir = os.path.join(prefix, "checkpoints", CACHE_NAME)
#sae_256_8 = train_sae(embeddings=train_embeddings, M=256, K=8, checkpoint_dir=checkpoint_dir, val_embeddings=val_embeddings)
#sae_32_4 = train_sae(embeddings=train_embeddings, M=32, K=4, checkpoint_dir=checkpoint_dir, val_embeddings=val_embeddings)
sae_64_4 = train_sae(embeddings=train_embeddings,M=64, K=4, checkpoint_dir=checkpoint_dir, val_embeddings=val_embeddings)
sae_32_2 = train_sae(embeddings=train_embeddings,M=32, K=2, checkpoint_dir=checkpoint_dir, val_embeddings=val_embeddings)
sae_list = [sae_64_4, sae_32_2]
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# Early stopping triggered after 90 epochs
# Saved model to ../checkpoints/cmf_quickstart_text-embedding-3-small/SAE_M=64_K=4.pt
#   0%|          | 0/100 [00:00<?, ?it/s]
# Early stopping triggered after 85 epochs
# Saved model to ../checkpoints/cmf_quickstart_text-embedding-3-small/SAE_M=32_K=2.pt

# %% [markdown]
# **Interpret neurons**
#
# Interpret a random subset of neurons in the SAE to sanity-check that the learned features, and their interpretations, seem reasonable. We generate and print labels for `n_random_neurons` neurons, and we also print out the top-activating texts for each neuron.

# %%
# This instruction will be included in the neuron interpretation prompt.
# The below instructions are specific to Yelp, but you can customize this for your task.
# If you don't pass in task-specific instructions, there is a generic instruction (see src/interpret_neurons.py);
# task-specific instructions are optional, but they help produce hypotheses at the desired level of specificity.

TASK_SPECIFIC_INSTRUCTIONS = """"All of the texts are public comments submitted on behalf of the 2023 California Mathemtatics Framework that provides instructional guidance for educators.
Features should describe a specific aspect of the public comment. For example:
- "mentions the impact it will have on students"
- "critiques the way math should be taught'\""""

# Interpret random neurons
results = interpret_sae(
    texts=texts,
    embeddings=train_embeddings,
    sae=sae_list,
    n_random_neurons=5,
    print_examples_n=3,
    task_specific_instructions=TASK_SPECIFIC_INSTRUCTIONS
)
# Out:
# Computing activations (batchsize=16384):   0%|          | 0/1 [00:00<?, ?it/s]
# Computing activations (batchsize=16384):   0%|          | 0/1 [00:00<?, ?it/s]
# Activations shape: (571, 96)
# Generating 1 interpretation(s) per neuron:   0%|          | 0/5 [00:00<?, ?it/s]
# Neuron 19 (from SAE M=64, K=4): mentions legal challenges or lawsuits related to educational practices
#
# Top activating examples:
# 1. please do not adopt the draft framework this experiment failed in sfusd and we cant allow that experiment to further harm californias students please see attached comments  ...
# 2. this failed in sf and will fail our schools ...
# 3. dear president linda darlinghammond and state board of education members attached you will find correspondence concerning agenda item 17 ð action to set aside approval of mayacamas charter middle school petition thank you for your consideration sincerely ricardo j soto hehimhis chief advocacy officer and general counsel california charter school association it also cited extensively from jo boaler who has a history of citing researchers who say she misrepresents their work and who threatened a black uc berkeley professor with the police in response to his mild criticism of high speaking fees the framework also cites blog posts advertising the sale of her products which i view as an inappropriate financial benefit ...
# ----------------------------------------------------------------------------------------------------
#
# Neuron 35 (from SAE M=64, K=4): mentions that math content standards are being replaced by big ideas not written by mathematicians
#
# Top activating examples:
# 1. math content standards are being replaced by big ideas not written by mathematicians  ...
# 2. math content standards are being replaced by big ideas not written by mathematicians  ...
# 3. math content standards are being replaced by big ideas not written by mathematicians  ...
# ----------------------------------------------------------------------------------------------------
#
# Neuron 40 (from SAE M=64, K=4): mentions an attached letter or comment
#
# Top activating examples:
# 1. please see my attached letter ...
# 2. please see attached ...
# 3. please see the attached letter  x ...
# ----------------------------------------------------------------------------------------------------
#
# Neuron 46 (from SAE M=64, K=4): mentions personal experiences or perspectives to support their argument
#
# Top activating examples:
# 1. i fully support this curriculum as retired school psychologist and special education teacher creating a curriculum that is both inclusive of diverse learning styles and considers the cultural differences is invaluable  ...
# 2. as a former high school teacher i highly recommend adopting 11 ...
# 3. this supports how children learn best i am a retired special education teacher and support this adoption  ...
# ----------------------------------------------------------------------------------------------------
#
# Neuron 67 (from SAE M=32, K=2): provides detailed suggestions or corrections for specific sections, lines, or pages of the mathematics framework
#
# Top activating examples:
# 1. submitting clarifying language for chapter 8 ...
# 2. hello board members i read through the current version of chapter 3 number sense for grades tk6 and have attached a short list of several items that need correction plus a suggestion or two regarding wording hope this is helpful and timely for you thanks for keeping things moving along katy corrections to chapter 3 p 4 line 62 ð incomplete sentence similarly chapter 4 describes how the standards for mathematical practice can be instilled across grade levels and chapter 5 describes progressions for suggestion é chapter 5 describes progressions for the development of data science for all the grades k12 p 11 line 2489 ð redundancy they select or invent sensible calculation strategies to make sense in a particular situation developing as mathematical thinkers suggestion é  they select or invent sensible calculation strategies to apply in a particular situation developing as mathematical thinkers p 20 lines 499501  the two diagrams labels are reversed suggestion  instead the upper image should be labeled 3  4 and [... rest of text is truncated]...
# 3. 1chapter 8 needs revision to show that the two pathways through the high school curriculum are alternative sequences through the same content stipulated in the california standards the current draft gives the impression that the content differs substantially in the standards and therefore in chapter 8 functions and modeling with functions should be in the foreground for both pathways the study of functions and their use to model real world phenomena is foundational for calculus and for data science it is also a more intuitive and motivating path to more advanced mathematics for students from varied backgrounds with varied aspirations 2appendix a pages 2 through 8 should be deleted or rewritten to align with the content in chapter 8 i recommend deletion because it is redundant with chapter 8   ...
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# **Generate hypotheses**
#
# Generate hypotheses which are predictive of the target variable.
#
# The `selection_method` parameter defines how we compute neuron predictiveness (see `src/select_neurons.py` for more details):
# - "separation_score": E[target | top-activating examples] - E[target | zero-activating examples]
# - "correlation": pearson(neuron activations, target variable)
# - "lasso": select N nonzero features with an L1 regularized model
#
# This cell outputs a dataframe with the following columns:
# - `neuron_idx`: The index of the neuron in the SAE (if you're using multiple SAEs, this will be a global index across all of them).
# - `source_sae`: The SAE that the neuron was selected from.
# - `target_{selection_method}`: The predictiveness of the neuron for the target variable, using the selected `selection_method`.
# - `interpretation`: The natural language interpretation of the neuron.
# - `interp_fidelity_score`: The F1 fidelity score for how well the neuron's interpretation actually corresponds to its activation pattern.

# %%
selection_method = "correlation"
results = generate_hypotheses(
    texts=texts,
    labels=labels,
    embeddings=embeddings,
    sae=sae_list,
    cache_name=CACHE_NAME,
    selection_method=selection_method,
    n_selected_neurons=20,
    n_candidate_interpretations=1,
    task_specific_instructions=TASK_SPECIFIC_INSTRUCTIONS
)

print("\nMost predictive features of Yelp reviews:")
pd.set_option('display.max_colwidth', None)
display(results.sort_values(by=f"target_{selection_method}", ascending=False))
pd.reset_option('display.max_colwidth')
# Out:
# Embeddings shape: (571, 1536)
# Computing activations (batchsize=16384):   0%|          | 0/1 [00:00<?, ?it/s]
# Computing activations (batchsize=16384):   0%|          | 0/1 [00:00<?, ?it/s]
# Activations shape: (571, 96)
#
# Step 1: Selecting top 20 predictive neurons
#
# Step 2: Interpreting selected neurons
# Generating 1 interpretation(s) per neuron:   0%|          | 0/20 [00:00<?, ?it/s]
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 30000, Used 27728, Requested 4825. Please try again in 5.106s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 20.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 30000, Used 29666, Requested 4537. Please try again in 8.406s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 20.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 30000, Used 29551, Requested 4646. Please try again in 8.394s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 20.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 30000, Used 28243, Requested 4716. Please try again in 5.918s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 20.0s... (2/3)
#
# Step 3: Scoring Interpretations
# Warning: Only found 41 examples with positive activation, using all available
# Warning: Only found 32 examples with positive activation, using all available
# Warning: Only found 22 examples with positive activation, using all available
# Warning: Only found 20 examples with positive activation, using all available
# Warning: Only found 25 examples with positive activation, using all available
# Warning: Only found 45 examples with positive activation, using all available
# Warning: Only found 40 examples with positive activation, using all available
# Warning: Only found 24 examples with positive activation, using all available
# Warning: Only found 41 examples with positive activation, using all available
# Found 0 cached items; annotating 1840 uncached items
# Scoring neuron interpretation fidelity (20 neurons; 1 candidate interps per neuron; 100 examples to score each…
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199725, Requested 814. Please try again in 161ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199733, Requested 760. Please try again in 147ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199732, Requested 760. Please try again in 147ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199721, Requested 761. Please try again in 144ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
#
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199729, Requested 760. Please try again in 146ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199713, Requested 814. Please try again in 158ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199700, Requested 814. Please try again in 154ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199684, Requested 814. Please try again in 149ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199575, Requested 920. Please try again in 148ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199535, Requested 978. Please try again in 153ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199513, Requested 977. Please try again in 147ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199512, Requested 975. Please try again in 146ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199482, Requested 989. Please try again in 141ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199480, Requested 998. Please try again in 143ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199616, Requested 814. Please try again in 129ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199485, Requested 981. Please try again in 139ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199607, Requested 760. Please try again in 110ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199582, Requested 760. Please try again in 102ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199563, Requested 760. Please try again in 96ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199534, Requested 760. Please try again in 88ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199533, Requested 770. Please try again in 90ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199354, Requested 763. Please try again in 35ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199398, Requested 977. Please try again in 112ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199382, Requested 978. Please try again in 108ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199366, Requested 989. Please try again in 106ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199353, Requested 998. Please try again in 105ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199907, Requested 981. Please try again in 266ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199541, Requested 618. Please try again in 47ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199528, Requested 814. Please try again in 102ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199484, Requested 814. Please try again in 89ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199370, Requested 760. Please try again in 39ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199538, Requested 604. Please try again in 42ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199547, Requested 745. Please try again in 87ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199485, Requested 814. Please try again in 89ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199905, Requested 1013. Please try again in 275ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199691, Requested 760. Please try again in 135ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199432, Requested 920. Please try again in 105ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199351, Requested 975. Please try again in 97ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199720, Requested 814. Please try again in 160ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199530, Requested 989. Please try again in 155ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199499, Requested 998. Please try again in 149ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199488, Requested 981. Please try again in 140ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199586, Requested 814. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199759, Requested 760. Please try again in 155ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199702, Requested 760. Please try again in 138ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199704, Requested 770. Please try again in 142ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199709, Requested 760. Please try again in 140ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199648, Requested 760. Please try again in 122ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199633, Requested 814. Please try again in 134ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199448, Requested 760. Please try again in 62ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199318, Requested 995. Please try again in 93ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199682, Requested 760. Please try again in 132ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199616, Requested 814. Please try again in 129ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199596, Requested 814. Please try again in 123ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199451, Requested 999. Please try again in 135ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199368, Requested 1013. Please try again in 114ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199280, Requested 814. Please try again in 28ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199343, Requested 977. Please try again in 96ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199346, Requested 978. Please try again in 97ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199355, Requested 920. Please try again in 82ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199370, Requested 975. Please try again in 103ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199526, Requested 760. Please try again in 85ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199428, Requested 862. Please try again in 87ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199738, Requested 763. Please try again in 150ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199731, Requested 770. Please try again in 150ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199555, Requested 945. Please try again in 150ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199681, Requested 753. Please try again in 130ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199746, Requested 770. Please try again in 154ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199725, Requested 760. Please try again in 145ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199696, Requested 814. Please try again in 153ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199701, Requested 760. Please try again in 138ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199495, Requested 760. Please try again in 76ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199673, Requested 814. Please try again in 146ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199628, Requested 814. Please try again in 132ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199491, Requested 1013. Please try again in 151ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199699, Requested 814. Please try again in 153ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199566, Requested 672. Please try again in 71ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199568, Requested 750. Please try again in 95ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199736, Requested 618. Please try again in 106ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# ...
#
#
#  Missing annotation for text:
# i strongly support the idea of teaching for equity and engagement which lays out the following five components of equitable math education 1 plan teaching around big ideas 2 use open engaging tasks 3 teach toward social justice 4 invite student questions and conjectures 5 prioritize reasoning and justification this is how math education supports democracy as a veteran of over 40 years of teaching mathematics at the secondary level i found this to help combat math anxiety and improve student math...
# Interp: explicitly supports the adoption or approval of the 2023 California Mathematics Framework
#
# Available keys for interp: ['as a former elementary and secondary mathematics teacher a current education researcher and teacher educator and a parent i write to share my support of the ca framework research shows that when students have access to highquality curricular resources and pedagogy  as is recommended by the framework they do better in mathematics in terms of achievement outcomes participation patterns and success in mathematics pathways longterm the approach outlined in the framework is equitable effective conceptual and empowering for students the framework will support ca mathematics teachers students and families with a more humanizing approach to mathematics that supports students to develop deep conceptual understanding of content to connect it to their lives and to other subjects and to author their own ideas  ', 'adopting the new mathematics framework would allow mathematics teachers throughout california to provide a more comprehensive inclusive and meaningful curriculum for the diverse k12 students within the state this would also allow for the support and implementation of pedagogical approaches that mathematics education literature has demonstrated is most effective in student learning   ', 'please dont implement the proposed ca math framework these changes disadvantage the very people you are trying to help it has been a total failure at sfusd and will injure cas ability to compete in the future   ']...
#
#
#  Missing annotation for text:
# we need evidence based policy not the untested policy notions of a non profit company  boaler california needs to follow best practice not experiment on its children  ...
# Interp: explicitly supports the adoption or approval of the 2023 California Mathematics Framework
#
# Available keys for interp: ['as a former elementary and secondary mathematics teacher a current education researcher and teacher educator and a parent i write to share my support of the ca framework research shows that when students have access to highquality curricular resources and pedagogy  as is recommended by the framework they do better in mathematics in terms of achievement outcomes participation patterns and success in mathematics pathways longterm the approach outlined in the framework is equitable effective conceptual and empowering for students the framework will support ca mathematics teachers students and families with a more humanizing approach to mathematics that supports students to develop deep conceptual understanding of content to connect it to their lives and to other subjects and to author their own ideas  ', 'adopting the new mathematics framework would allow mathematics teachers throughout california to provide a more comprehensive inclusive and meaningful curriculum for the diverse k12 students within the state this would also allow for the support and implementation of pedagogical approaches that mathematics education literature has demonstrated is most effective in student learning   ', 'please dont implement the proposed ca math framework these changes disadvantage the very people you are trying to help it has been a total failure at sfusd and will injure cas ability to compete in the future   ']...
#
#
#  Missing annotation for text:
# we should look at states such as massachusetts utah and idaho that have the highest naep scores in math for guidance rather than trying to reinvent the wheel equity and inclusion is important but it should be approached from a lense of social studies and civics rather than hard sciences a mathematics framework should be centered on physical laws rather than social constructs there is room for both in the california school curriculum  ...
# Interp: explicitly supports the adoption or approval of the 2023 California Mathematics Framework
#
# Available keys for interp: ['as a former elementary and secondary mathematics teacher a current education researcher and teacher educator and a parent i write to share my support of the ca framework research shows that when students have access to highquality curricular resources and pedagogy  as is recommended by the framework they do better in mathematics in terms of achievement outcomes participation patterns and success in mathematics pathways longterm the approach outlined in the framework is equitable effective conceptual and empowering for students the framework will support ca mathematics teachers students and families with a more humanizing approach to mathematics that supports students to develop deep conceptual understanding of content to connect it to their lives and to other subjects and to author their own ideas  ', 'adopting the new mathematics framework would allow mathematics teachers throughout california to provide a more comprehensive inclusive and meaningful curriculum for the diverse k12 students within the state this would also allow for the support and implementation of pedagogical approaches that mathematics education literature has demonstrated is most effective in student learning   ', 'please dont implement the proposed ca math framework these changes disadvantage the very people you are trying to help it has been a total failure at sfusd and will injure cas ability to compete in the future   ']...
#
#
#  Missing annotation for text:
# oppose ...
# Interp: explicitly supports the adoption or approval of the 2023 California Mathematics Framework
#
# Available keys for interp: ['as a former elementary and secondary mathematics teacher a current education researcher and teacher educator and a parent i write to share my support of the ca framework research shows that when students have access to highquality curricular resources and pedagogy  as is recommended by the framework they do better in mathematics in terms of achievement outcomes participation patterns and success in mathematics pathways longterm the approach outlined in the framework is equitable effective conceptual and empowering for students the framework will support ca mathematics teachers students and families with a more humanizing approach to mathematics that supports students to develop deep conceptual understanding of content to connect it to their lives and to other subjects and to author their own ideas  ', 'adopting the new mathematics framework would allow mathematics teachers throughout california to provide a more comprehensive inclusive and meaningful curriculum for the diverse k12 students within the state this would also allow for the support and implementation of pedagogical approaches that mathematics education literature has demonstrated is most effective in student learning   ', 'please dont implement the proposed ca math framework these changes disadvantage the very people you are trying to help it has been a total failure at sfusd and will injure cas ability to compete in the future   ']...
#
#
#  Missing annotation for text:
# our students are failing at epic rates leave this marxist math out of the curriculum political agendas should not be infused with teaching our students fundamental math skills   ...
# Interp: explicitly supports the adoption or approval of the 2023 California Mathematics Framework
#
# Available keys for interp: ['as a former elementary and secondary mathematics teacher a current education researcher and teacher educator and a parent i write to share my support of the ca framework research shows that when students have access to highquality curricular resources and pedagogy  as is recommended by the framework they do better in mathematics in terms of achievement outcomes participation patterns and success in mathematics pathways longterm the approach outlined in the framework is equitable effective conceptual and empowering for students the framework will support ca mathematics teachers students and families with a more humanizing approach to mathematics that supports students to develop deep conceptual understanding of content to connect it to their lives and to other subjects and to author their own ideas  ', 'adopting the new mathematics framework would allow mathematics teachers throughout california to provide a more comprehensive inclusive and meaningful curriculum for the diverse k12 students within the state this would also allow for the support and implementation of pedagogical approaches that mathematics education literature has demonstrated is most effective in student learning   ', 'please dont implement the proposed ca math framework these changes disadvantage the very people you are trying to help it has been a total failure at sfusd and will injure cas ability to compete in the future   ']...
#
#
#  Missing annotation for text:
# our children deserve the highest standards in math requirements and curriculum do not adopt this new math framework that focuses on incorporating social justice diversity equity and inclusion standards in a math curriculum keep the math standards objective and free from political correctness our children deserve to be proficient in math so they can be future leaders in science and engineering technology and other industries   ...
# Interp: explicitly supports the adoption or approval of the 2023 California Mathematics Framework
#
# Available keys for interp: ['as a former elementary and secondary mathematics teacher a current education researcher and teacher educator and a parent i write to share my support of the ca framework research shows that when students have access to highquality curricular resources and pedagogy  as is recommended by the framework they do better in mathematics in terms of achievement outcomes participation patterns and success in mathematics pathways longterm the approach outlined in the framework is equitable effective conceptual and empowering for students the framework will support ca mathematics teachers students and families with a more humanizing approach to mathematics that supports students to develop deep conceptual understanding of content to connect it to their lives and to other subjects and to author their own ideas  ', 'adopting the new mathematics framework would allow mathematics teachers throughout california to provide a more comprehensive inclusive and meaningful curriculum for the diverse k12 students within the state this would also allow for the support and implementation of pedagogical approaches that mathematics education literature has demonstrated is most effective in student learning   ', 'please dont implement the proposed ca math framework these changes disadvantage the very people you are trying to help it has been a total failure at sfusd and will injure cas ability to compete in the future   ']...
#
#
#  Missing annotation for text:
# please approve the new math framework coming from a former teacher for the last 7 years this is what kids need to better grasp complex math concepts   ...
# Interp: explicitly supports the adoption or approval of the 2023 California Mathematics Framework
#
# Available keys for interp: ['as a former elementary and secondary mathematics teacher a current education researcher and teacher educator and a parent i write to share my support of the ca framework research shows that when students have access to highquality curricular resources and pedagogy  as is recommended by the framework they do better in mathematics in terms of achievement outcomes participation patterns and success in mathematics pathways longterm the approach outlined in the framework is equitable effective conceptual and empowering for students the framework will support ca mathematics teachers students and families with a more humanizing approach to mathematics that supports students to develop deep conceptual understanding of content to connect it to their lives and to other subjects and to author their own ideas  ', 'adopting the new mathematics framework would allow mathematics teachers throughout california to provide a more comprehensive inclusive and meaningful curriculum for the diverse k12 students within the state this would also allow for the support and implementation of pedagogical approaches that mathematics education literature has demonstrated is most effective in student learning   ', 'please dont implement the proposed ca math framework these changes disadvantage the very people you are trying to help it has been a total failure at sfusd and will injure cas ability to compete in the future   ']...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 selection_method = "correlation"
# ----> 2 results = generate_hypotheses(
#       3     texts=texts,
#       4     labels=labels,
#       5     embeddings=embeddings,
#       6     sae=sae_list,
#       7     cache_name=CACHE_NAME,
#       8     selection_method=selection_method,
#       9     n_selected_neurons=20,
#      10     n_candidate_interpretations=1,
#      11     task_specific_instructions=TASK_SPECIFIC_INSTRUCTIONS
#      12 )
#      14 print("\nMost predictive features of Yelp reviews:")
#      15 pd.set_option('display.max_colwidth', None)
#
# File ~/Documents/HypotheSAEs/hypothesaes/quickstart.py:330, in generate_hypotheses(texts, labels, embeddings, sae, cache_name, classification, selection_method, n_selected_neurons, interpreter_model, annotator_model, n_examples_for_interpretation, max_words_per_example, interpret_temperature, max_interpretation_tokens, n_candidate_interpretations, n_scoring_examples, scoring_metric, n_workers_interpretation, n_workers_annotation, task_specific_instructions)
#     328 print(f"\nStep 3: Scoring Interpretations")
#     329 scoring_config = ScoringConfig(n_examples=n_scoring_examples)
# --> 330 metrics = interpreter.score_interpretations(
#     331     texts=texts,
#     332     activations=activations,
#     333     interpretations=interpretations,
#     334     config=scoring_config
#     335 )
#     337 for idx, score in zip(selected_neurons, scores):
#     338     # Find best interpretation and its score using max()
#     339     best_interp = max(
#     340         interpretations[idx],
#     341         key=lambda interp: metrics[idx][interp][scoring_metric]
#     342     )
#
# File ~/Documents/HypotheSAEs/hypothesaes/interpret_neurons.py:415, in NeuronInterpreter.score_interpretations(self, texts, activations, interpretations, config)
#     412             annot.append(annotations[interp][text])
#     414         if annot:  # Only compute metrics if we have annotations
# --> 415             all_metrics[neuron_idx][interp] = self._compute_metrics(
#     416                 annotations=np.array(annot),
#     417                 labels=neuron_scoring_info['binarized_activations'],
#     418                 activations=neuron_scoring_info['activations']
#     419             )
#     421 return all_metrics
#
# File ~/Documents/HypotheSAEs/hypothesaes/interpret_neurons.py:328, in NeuronInterpreter._compute_metrics(self, annotations, labels, activations)
#     325 if not (1 in labels and 0 in labels):
#     326     return {"recall": 0.0, "precision": 0.0, "f1": 0.0, "correlation": 0.0}
# --> 328 true_pos = np.mean(annotations[labels == 1])
#     329 false_pos = np.mean(annotations[labels == 0])
#     330 precision = 1 - false_pos
#
# IndexError: boolean index did not match indexed array along axis 0; size of axis is 6 but size of corresponding boolean axis is 100

# %% [markdown]
# **Evaluate held-out generalization**
#
# Finally, we evaluate whether these are good hypotheses by testing whether their natural language interpretations can predict the target variable.
#
# We compute annotations for each hypothesized concept on a holdout set (not seen during SAE training & feature selection).
#
# After annotation, we output a dataframe with the following columns:
# - `hypothesis`: The natural language hypothesis (which came from interpreting a predictive neuron in the SAE)
# - `separation_score`: How much the target variable differs when the concept is present vs. absent (i.e., $E[Y\mid\text{concept} = 1] - E[Y\mid\text{concept} = 0]$).
# - `separation_pvalue`: The t-test p-value of the null hypothesis that the separation score is 0 (i.e., the concept is not associated with the target variable).
# - `regression_coef`: The coefficient of the concept in a multivariate linear regression of the target variable on all concepts.
# - `regression_pval`: The p-value of the null hypothesis that the regression coefficient is 0.
# - `feature_prevalence`: The fraction of examples that contain the concept.
#
# Additionally, we output the evaluation metrics used in the paper:
# - Significant hypotheses: the number of hypotheses that are significant in the multivariate regression at a specified significance level (default $0.1$) after Bonferroni correction. You can pass in a different significance level using the `corrected_pval_threshold` parameter.
# - AUC or $R^2$: how well the hypotheses collectively predict the target variable in the multivariate regression.

# %%
holdout_df = pd.read_json(os.path.join(base_dir, "yelp-demo-holdout-2K.json"), lines=True)
holdout_texts = holdout_df['text'].tolist()
holdout_labels = holdout_df['stars'].values

metrics, evaluation_df = evaluate_hypotheses(
    hypotheses_df=results,
    texts=holdout_texts,
    labels=holdout_labels,
    cache_name=CACHE_NAME,
)

pd.set_option('display.max_colwidth', None)
display(evaluation_df)
pd.reset_option('display.max_colwidth')

print("\nHoldout Set Metrics:")
print(f"R² Score: {metrics['r2']:.3f}")
print(f"Significant hypotheses: {metrics['Significant'][0]}/{metrics['Significant'][1]} " 
      f"(p < {metrics['Significant'][2]:.3e})")
# Out:
# Step 1: Annotating texts with 5 hypotheses
# Found 0 cached items; annotating 10000 uncached items
# Annotating:   0%|          | 0/10000 [00:00<?, ?it/s]
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199677, Requested 630. Please try again in 92ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199647, Requested 615. Please try again in 78ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199476, Requested 737. Please try again in 63ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199766, Requested 725. Please try again in 147ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199756, Requested 742. Please try again in 149ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199718, Requested 733. Please try again in 135ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199663, Requested 816. Please try again in 143ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199695, Requested 623. Please try again in 95ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199628, Requested 662. Please try again in 87ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199664, Requested 660. Please try again in 97ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199585, Requested 717. Please try again in 90ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199579, Requested 657. Please try again in 70ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199560, Requested 727. Please try again in 86ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199559, Requested 724. Please try again in 84ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199557, Requested 721. Please try again in 83ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199568, Requested 709. Please try again in 83ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199528, Requested 752. Please try again in 84ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199534, Requested 747. Please try again in 84ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199522, Requested 743. Please try again in 79ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199519, Requested 735. Please try again in 76ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199583, Requested 750. Please try again in 99ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199589, Requested 620. Please try again in 62ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199586, Requested 616. Please try again in 60ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199644, Requested 608. Please try again in 75ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199727, Requested 601. Please try again in 98ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199640, Requested 706. Please try again in 103ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199571, Requested 742. Please try again in 93ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199627, Requested 750. Please try again in 113ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199579, Requested 816. Please try again in 118ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199739, Requested 657. Please try again in 118ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199666, Requested 735. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199651, Requested 727. Please try again in 113ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199728, Requested 663. Please try again in 117ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199565, Requested 736. Please try again in 90ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199711, Requested 666. Please try again in 113ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199743, Requested 675. Please try again in 125ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199647, Requested 663. Please try again in 93ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199517, Requested 678. Please try again in 58ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199786, Requested 598. Please try again in 115ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199559, Requested 613. Please try again in 51ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199322, Requested 706. Please try again in 8ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199651, Requested 724. Please try again in 112ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199588, Requested 742. Please try again in 99ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199937, Requested 737. Please try again in 202ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199629, Requested 725. Please try again in 106ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199422, Requested 717. Please try again in 41ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199455, Requested 727. Please try again in 54ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199429, Requested 816. Please try again in 73ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199726, Requested 735. Please try again in 138ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199383, Requested 758. Please try again in 42ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199652, Requested 718. Please try again in 111ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199935, Requested 736. Please try again in 201ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199555, Requested 737. Please try again in 87ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199558, Requested 725. Please try again in 84ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199530, Requested 717. Please try again in 74ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199605, Requested 715. Please try again in 96ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199582, Requested 727. Please try again in 92ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199374, Requested 709. Please try again in 24ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199276, Requested 816. Please try again in 27ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199570, Requested 724. Please try again in 88ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199639, Requested 707. Please try again in 103ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199670, Requested 608. Please try again in 83ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199622, Requested 722. Please try again in 103ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199731, Requested 599. Please try again in 99ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199399, Requested 842. Please try again in 72ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199531, Requested 848. Please try again in 113ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199680, Requested 579. Please try again in 77ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199655, Requested 594. Please try again in 74ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199841, Requested 562. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199783, Requested 571. Please try again in 106ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199637, Requested 664. Please try again in 90ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199526, Requested 667. Please try again in 57ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199594, Requested 675. Please try again in 80ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199736, Requested 647. Please try again in 114ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199709, Requested 656. Please try again in 109ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199654, Requested 666. Please try again in 96ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199381, Requested 895. Please try again in 82ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199718, Requested 610. Please try again in 98ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199622, Requested 724. Please try again in 103ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199463, Requested 595. Please try again in 17ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199708, Requested 608. Please try again in 94ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199341, Requested 919. Please try again in 78ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199291, Requested 866. Please try again in 47ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199414, Requested 849. Please try again in 78ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199786, Requested 597. Please try again in 114ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per min (RPM): Limit 500, Used 500, Requested 1. Please try again in 120ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199600, Requested 705. Please try again in 91ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on tokens per min (TPM): Limit 200000, Used 199456, Requested 711. Please try again in 50ms. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'tokens', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# ...
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# Failed to annotate after 3 attempts: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# API error: Error code: 429 - {'error': {'message': 'Rate limit reached for gpt-4o-mini in organization org-hHrkX2MdWscmD3gh0WKtNR1z on requests per day (RPD): Limit 10000, Used 10000, Requested 1. Please try again in 8.64s. Visit https://platform.openai.com/account/rate-limits to learn more.', 'type': 'requests', 'param': None, 'code': 'rate_limit_exceeded'}}; retrying in 10.0s... (2/3)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/Documents/HypotheSAEs/hypothesaes/annotate.py:109, in _parallel_annotate(tasks, n_workers, cache, cache_path, results, progress_desc, show_progress, **kwargs)
#     104 iterator = tqdm(concurrent.futures.as_completed(future_to_task),
#     105                total=len(tasks),
#     106                desc=progress_desc,
#     107                disable=not show_progress)
# --> 109 for future in iterator:
#     110     text, concept = future_to_task[future]
#
# File ~/Documents/HypotheSAEs/venv/lib/python3.9/site-packages/tqdm/notebook.py:250, in tqdm_notebook.__iter__(self)
#     249 it = super().__iter__()
# --> 250 for obj in it:
#     251     # return super(tqdm...) will not catch exception
#     252     yield obj
#
# File ~/Documents/HypotheSAEs/venv/lib/python3.9/site-packages/tqdm/std.py:1181, in tqdm.__iter__(self)
#    1180 try:
# -> 1181     for obj in iterable:
#    1182         yield obj
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/concurrent/futures/_base.py:245, in as_completed(fs, timeout)
#     241         raise TimeoutError(
#     242                 '%d (of %d) futures unfinished' % (
#     243                 len(pending), total_futures))
# --> 245 waiter.event.wait(wait_timeout)
#     247 with waiter.lock:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/threading.py:574, in Event.wait(self, timeout)
#     573 if not signaled:
# --> 574     signaled = self._cond.wait(timeout)
#     575 return signaled
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/threading.py:312, in Condition.wait(self, timeout)
#     311 if timeout is None:
# --> 312     waiter.acquire()
#     313     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 5
#       2 holdout_texts = holdout_df['text'].tolist()
#       3 holdout_labels = holdout_df['stars'].values
# ----> 5 metrics, evaluation_df = evaluate_hypotheses(
#       6     hypotheses_df=results,
#       7     texts=holdout_texts,
#       8     labels=holdout_labels,
#       9     cache_name=CACHE_NAME,
#      10 )
#      12 pd.set_option('display.max_colwidth', None)
#      13 display(evaluation_df)
#
# File ~/Documents/HypotheSAEs/hypothesaes/quickstart.py:393, in evaluate_hypotheses(hypotheses_df, texts, labels, cache_name, annotator_model, max_words_per_example, classification, n_workers_annotation, corrected_pval_threshold)
#     391 # Step 1: Get annotations for each hypothesis on the texts
#     392 print(f"Step 1: Annotating texts with {len(hypotheses)} hypotheses")
# --> 393 hypothesis_annotations = annotate_texts_with_concepts(
#     394     texts=texts,
#     395     concepts=hypotheses,
#     396     max_words_per_example=max_words_per_example,
#     397     model=annotator_model,
#     398     cache_name=cache_name,
#     399     n_workers=n_workers_annotation,
#     400 )
#     402 # Step 2: Evaluate annotations against the true labels
#     403 print("Step 2: Computing predictiveness of hypothesis annotations")
#
# File ~/Documents/HypotheSAEs/hypothesaes/annotate.py:211, in annotate_texts_with_concepts(texts, concepts, cache_name, progress_desc, show_progress, **kwargs)
#     208 tasks = [(text, concept) for text in texts for concept in concepts]
#     210 # Use the annotate function to process tasks
# --> 211 results = annotate(
#     212     tasks=tasks,
#     213     cache_path=os.path.join(CACHE_DIR, f"{cache_name}_hypothesis-eval.json") if cache_name else None,
#     214     n_workers=kwargs.pop('n_workers', DEFAULT_N_WORKERS),
#     215     show_progress=show_progress,
#     216     progress_desc=progress_desc,
#     217     **kwargs
#     218 )
#     220 # Reorganize results into arrays per concept
#     221 concept_arrays = {}
#
# File ~/Documents/HypotheSAEs/hypothesaes/annotate.py:178, in annotate(tasks, cache_path, n_workers, show_progress, **kwargs)
#     176 # Annotate uncached tasks
#     177 if uncached_tasks:
# --> 178     _parallel_annotate(
#     179         tasks=uncached_tasks,
#     180         n_workers=n_workers,
#     181         cache=cache,
#     182         cache_path=cache_path,
#     183         results=results,
#     184         show_progress=show_progress,
#     185         **kwargs
#     186     )
#     188 # Save cache if path provided
#     189 if cache_path:
#
# File ~/Documents/HypotheSAEs/hypothesaes/annotate.py:121, in _parallel_annotate(tasks, n_workers, cache, cache_path, results, progress_desc, show_progress, **kwargs)
#     119         except Exception as e:
#     120             retry_tasks.append((text, concept))
# --> 121             print(f"Failed to annotate text for concept '{concept}': {e}")
#     123 # Retry failed tasks sequentially
#     124 if retry_tasks:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/concurrent/futures/_base.py:636, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     635 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 636     self.shutdown(wait=True)
#     637     return False
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/concurrent/futures/thread.py:229, in ThreadPoolExecutor.shutdown(self, wait, cancel_futures)
#     227 if wait:
#     228     for t in self._threads:
# --> 229         t.join()
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/threading.py:1053, in Thread.join(self, timeout)
#    1050     raise RuntimeError("cannot join current thread")
#    1052 if timeout is None:
# -> 1053     self._wait_for_tstate_lock()
#    1054 else:
#    1055     # the behavior of a negative timeout isn't documented, but
#    1056     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1057     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/threading.py:1069, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1067 if lock is None:  # already determined that the C code is done
#    1068     assert self._is_stopped
# -> 1069 elif lock.acquire(block, timeout):
#    1070     lock.release()
#    1071     self._stop()
#
# KeyboardInterrupt:
